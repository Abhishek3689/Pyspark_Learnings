# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('test_spark').getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/10/12 14:12:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/10/12 14:12:19 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f80ec55ce39e:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test_spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_spark=spark.read.csv('test1.csv',header=True,inferSchema=True)

# %%
df_spark
# Out:
# DataFrame[Name: string, Age: int, Experience: int]

# %%
df_spark.show()
# Out:
# +---------+---+----------+
# |     Name|Age|Experience|
# +---------+---+----------+
# |Abhishek | 34|        10|
# |   Nitesh| 30|         7|
# | Sangeeta| 33|         8|
# |  Anamika| 36|        13|
# +---------+---+----------+

# %%
df_spark.describe().show()
# Out:
# +-------+---------+-----------------+------------------+
# |summary|     Name|              Age|        Experience|
# +-------+---------+-----------------+------------------+
# |  count|        4|                4|                 4|
# |   mean|     null|            33.25|               9.5|
# | stddev|     null|2.499999999999999|2.6457513110645903|
# |    min|Abhishek |               30|                 7|
# |    max| Sangeeta|               36|                13|
# +-------+---------+-----------------+------------------+

# %%
df_spark.select(['Name','Age']).show()
# Out:
# +---------+---+
# |     Name|Age|
# +---------+---+
# |Abhishek | 34|
# |   Nitesh| 30|
# | Sangeeta| 33|
# |  Anamika| 36|
# +---------+---+

# %%
df_spark.withColumn('Salary',df_spark['Experience']*10000).show()
# Out:
# +---------+---+----------+------+
# |     Name|Age|Experience|Salary|
# +---------+---+----------+------+
# |Abhishek | 34|        10|100000|
# |   Nitesh| 30|         7| 70000|
# | Sangeeta| 33|         8| 80000|
# |  Anamika| 36|        13|130000|
# +---------+---+----------+------+

# %%
df_spark.withColumnRenamed('Name','FirstName').show()
# Out:
# +---------+---+----------+
# |FirstName|Age|Experience|
# +---------+---+----------+
# |Abhishek | 34|        10|
# |   Nitesh| 30|         7|
# | Sangeeta| 33|         8|
# |  Anamika| 36|        13|
# +---------+---+----------+

# %%
df_spark.drop('Age').show()
# Out:
# +---------+----------+
# |     Name|Experience|
# +---------+----------+
# |Abhishek |        10|
# |   Nitesh|         7|
# | Sangeeta|         8|
# |  Anamika|        13|
# +---------+----------+
